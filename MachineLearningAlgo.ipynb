# %%
#Credentials import
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45654a33-ba2d-4347-af4f-72c02fc57ed0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45654a33-ba2d-4347-af4f-72c02fc57ed0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ev-eutopia-81a2d-firebase-adminsdk-yzo4h-508e86e4bd.json to ev-eutopia-81a2d-firebase-adminsdk-yzo4h-508e86e4bd.json

# %%
#Firebase App
#db is imported AS ff
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db as ff
from google.colab import files
database = "https://ev-eutopia-81a2d.firebaseio.com/"

cred = credentials.Certificate("ev-eutopia-81a2d-firebase-adminsdk-yzo4h-508e86e4bd.json" )
firebase_admin.initialize_app(cred, { 
    'databaseURL': 'https://ev-eutopia-81a2d.firebaseio.com/'
})



ref=ff.reference('users')
print(ref.get())
# Out:
# {'3P4rjXpAFYMN0N22w0UaJ70Xjay2': {'address': 'cgc landran, mohali', 'email': '1abhimanyukharwal.ak@gmail.com', 'first_name': 'Abhimanyu ', 'last_name': 'Kharwal', 'latitude': 30.686930600000004, 'longitude': 76.6648404}, 'EHTMGETYO3aIG3wGZqdv55bl85o2': {'address': 'Mohalla Ahmadiyya, Qadian, Punjab', 'email': 'fwaad.ahmad1@gmail.com', 'first_name': 'Fwaad', 'last_name': 'Ahmad', 'latitude': 31.814715999999997, 'longitude': 75.3776524}, 'IJBllVOcIYWKZN8u5vAwafPhnL72': {'address': 'Cgc Landran, Mohali', 'email': 'davidbekham@gmail.com', 'first_name': 'David', 'last_name': 'Beckham', 'latitude': 30.686930600000004, 'longitude': 76.6648404}, 'RO6WGE6FCkMxp3wlt6Pdzxo93zp2': {'address': '#45-B New Vivek Vihar, Ambala City', 'email': 'namanguptaa04@gmail.com', 'first_name': 'Naman', 'last_name': 'Gupta', 'latitude': 30.376298, 'longitude': 76.753843}, 'jFvEOvVRubMF7DOEhbM7KbB8Niy2': {'address': 'Mohalla Ahmadiyya, Qadian, Punjab', 'email': 'fwaad.ahmad2@gmail.com', 'first_name': 'Fwaad', 'last_name': 'Ahmad', 'latitude': 31.814715999999997, 'longitude': 75.3776524}, 'r11BDkl7d5asawRFnQyjx4Cp7ym2': {'address': 'Green avenue, street no.2,kotkapura road, muktsar,punjab', 'email': 'aameen@cgc.com', 'first_name': 'Aameen', 'last_name': 'Sharma', 'latitude': 30.4781864, 'longitude': 74.5305174, 'userId': 'r11BDkl7d5asawRFnQyjx4Cp7ym2', 'vehicle_type': 'Car 2'}, 'saWgWLV7aXN1EahBlTx60A1n40b2': {'address': 'Green avenue, street no.2,kotkapura road, muktasr,punjab', 'email': 'csecec1803107@gmail.com', 'first_name': 'Aameen', 'last_name': 'Sharma', 'latitude': 30.4781864, 'longitude': 74.5305174, 'userId': 'saWgWLV7aXN1EahBlTx60A1n40b2'}, 'tQvFssA5Nya0BC8rrmo2e8qIxXJ2': {'address': 'Mohalla Ahmadiyya, Qadian, punjab', 'email': 'fwaad.ahmad3@gmail.com', 'first_name': 'Fwaad', 'last_name': 'Ahmad', 'latitude': 31.814715999999997, 'longitude': 75.3776524}, 'w40OGCuukKbzTwysE6gx5H8dBlt1': {'address': 'Urban Estate Phase 2', 'email': 'arshiya2204@gmail.com', 'first_name': 'Arshiya ', 'last_name': 'Bhardawaj', 'latitude': 31.291291400000002, 'longitude': 75.5844334}, 'xNXVuHWbUXgOaeQocLSYr6dFaWL2': {'address': 'Dalhousie', 'email': 'ashitamahajandal@gmail.com', 'first_name': 'Ashita', 'last_name': 'mahajan', 'latitude': 44.636581199999995, 'longitude': -63.591655499999995}}

# %%
#Ml Algo
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from pylab import *
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.figure(figsize=(8,8))

#City coordinaates are the coordinates of the four boundaries of the city.

cityCoordinates = [[32.044984, 75.402493], [30.308945, 74.321969], [30.081049, 75.618356],[30.942350, 76.266549]]

X, labels_true = make_blobs(n_samples=1000, centers=cityCoordinates, cluster_std=0.1, random_state=0)
print (X)

xx, yy = zip(*X)
scatter(xx,yy)
show()
db = DBSCAN(eps=0.25, min_samples=10).fit(X)
core_samples = db.core_sample_indices_
labels = db.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
clustno = (n_clusters_)
clusters = [X[labels == i] for i in range(n_clusters_)]

for i in range (0,clustno):   
     cluster = clusters[i]
     plt.figure(figsize=(8,8))
     plt.scatter(cluster[:, 0], cluster[:, 1])
     kmeans = KMeans(n_clusters=1)
     kmeans = kmeans.fit(cluster)
     labels = kmeans.predict(cluster)
     plt.scatter(cluster[:,0], cluster[:,1], c=labels,)
     plt.title("K means clustring ")
     centroids =  kmeans.cluster_centers_
     plt.scatter(centroids[:,0],centroids[:,1])
    #  print(centroids)
     outputs = centroids
    #  print(outputs)
     for i in outputs:
       num = 0
       output = outputs[num]
       num = num+1
       print(output)
       a = str(output[0])
       b = str(output[1])
       #Data push to Firebase
       ref1 = ff.reference("Outputs/")
       print(ref1.get())
       ref1.push({
           'Latitude': a ,
           'Longitude': b
       })
       print(ref1.get())
# Out:
# [[31.9401287  75.26049121]
#  [32.22138923 75.44250872]
#  [30.89277045 76.38820677]
#  ...
#  [30.14176017 75.51353896]
#  [30.24420874 75.65613192]
#  [29.98380871 75.75297811]]
# [32.03964038 75.40276574]
# {'-MCo_r1lNdaux7j6QXp5': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCo_r8O5i5SU3wlvlUA': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCo_rEbmnKKVKbVDQeJ': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCo_rKfg7hS2eoXSSUg': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MCzIJ5-gfz207azFDyc': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCzIJH2ERUpxoDOFEWa': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCzIJRSznNRAtdUj04_': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCzIJyJe_gic-8c-Mq0': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDQcXQejX-w6xZRzOBp': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MDQcXWTKwZw3T7n5nLH': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MDQcXapGMQciB9KTe-i': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MDQcXeckYetql6uyBsR': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}}
# {'-MCo_r1lNdaux7j6QXp5': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCo_r8O5i5SU3wlvlUA': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCo_rEbmnKKVKbVDQeJ': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCo_rKfg7hS2eoXSSUg': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MCzIJ5-gfz207azFDyc': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCzIJH2ERUpxoDOFEWa': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCzIJRSznNRAtdUj04_': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCzIJyJe_gic-8c-Mq0': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDQcXQejX-w6xZRzOBp': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MDQcXWTKwZw3T7n5nLH': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MDQcXapGMQciB9KTe-i': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MDQcXeckYetql6uyBsR': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDVdrPw0X--_TIkhF3j': {'Latitude': 'a', 'Longitude': 'b'}}
# [30.93819086 76.27031552]
# {'-MCo_r1lNdaux7j6QXp5': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCo_r8O5i5SU3wlvlUA': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCo_rEbmnKKVKbVDQeJ': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCo_rKfg7hS2eoXSSUg': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-
{'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCo_r8O5i5SU3wlvlUA': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCo_rEbmnKKVKbVDQeJ': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCo_rKfg7hS2eoXSSUg': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MCzIJ5-gfz207azFDyc': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCzIJH2ERUpxoDOFEWa': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCzIJRSznNRAtdUj04_': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCzIJyJe_gic-8c-Mq0': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDQcXQejX-w6xZRzOBp': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MDQcXWTKwZw3T7n5nLH': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MDQcXapGMQciB9KTe-i': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MDQcXeckYetql6uyBsR': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDVdrPw0X--_TIkhF3j': {'Latitude': 'a', 'Longitude': 'b'}, '-MDVdraGiG7kWirR1dkt': {'Latitude': 'a', 'Longitude': 'b'}, '-MDVdromEiahqD-qDwJY': {'Latitude': 'a', 'Longitude': 'b'}, '-MDVds05jA5NHu8YCRTR': {'Latitude': 'a', 'Longitude': 'b'}}

# %%
#Data push to Firebase
ref1 = ff.reference("Outputs/")
llll = 2.22
print(ref1.get())
ref1.push({
  'Latitude': llll,
  'Longitude':'3.4'
})
print(ref1.get())
# Out:
# {'-MCo_r1lNdaux7j6QXp5': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCo_r8O5i5SU3wlvlUA': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCo_rEbmnKKVKbVDQeJ': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCo_rKfg7hS2eoXSSUg': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MCzIJ5-gfz207azFDyc': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCzIJH2ERUpxoDOFEWa': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCzIJRSznNRAtdUj04_': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCzIJyJe_gic-8c-Mq0': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDQcXQejX-w6xZRzOBp': {'Latitude': 32.03964037585337, 'Longitude': 75.40276573628016}, '-MDQcXWTKwZw3T7n5nLH': {'Latitude': 30.938190857501496, 'Longitude': 76.2703155165526}, '-MDQcXapGMQciB9KTe-i': {'Latitude': 30.301215486525066, 'Longitude': 74.31666671834533}, '-MDQcXeckYetql6uyBsR': {'Latitude': 30.089586686366005, 'Longitude': 75.61565771570636}}
# {'-MCo_r1lNdaux7j6QXp5': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCo_r8O5i5SU3wlvlUA': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCo_rEbmnKKVKbVDQeJ': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCo_rKfg7hS2eoXSSUg': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MCzIJ5-gfz207azFDyc': {'Latitude': '32.03964037585337', 'Longitude': '75.40276573628016'}, '-MCzIJH2ERUpxoDOFEWa': {'Latitude': '30.938190857501496', 'Longitude': '76.2703155165526'}, '-MCzIJRSznNRAtdUj04_': {'Latitude': '30.301215486525066', 'Longitude': '74.31666671834533'}, '-MCzIJyJe_gic-8c-Mq0': {'Latitude': '30.089586686366005', 'Longitude': '75.61565771570636'}, '-MDQcXQejX-w6xZRzOBp': {'Latitude': 32.03964037585337, 'Longitude': 75.40276573628016}, '-MDQcXWTKwZw3T7n5nLH': {'Latitude': 30.938190857501496, 'Longitude': 76.2703155165526}, '-MDQcXapGMQciB9KTe-i': {'Latitude': 30.301215486525066, 'Longitude': 74.31666671834533}, '-MDQcXeckYetql6uyBsR': {'Latitude': 30.089586686366005, 'Longitude': 75.61565771570636}, '-MDQe3WbEqInzV95qFVL': {'Latitude': 2.22, 'Longitude': '3.4'}}

# %%
#Value read code Snip
ref = ff.reference("coordinates")
print(ref.get())
ass = ref.get()
kin = ass.values()
print(kin)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5bb0fed82ba1> in <module>()
#       3 print(ref.get())
#       4 ass = ref.get()
# ----> 5 kin = ass.values()
#       6 print(kin)
#
# AttributeError: 'NoneType' object has no attribute 'values'
